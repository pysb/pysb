# %%
from earm.lopez_embedded import model
import numpy
import os
from visualization.model_visualization_reactions import ModelVisualization
from tropical.helper_functions import read_pars
from py2cytoscape.util import from_networkx
directory = '/Users/dionisio/PycharmProjects/tropical/examples/EARM/parameters_5000'
parameter_path = os.path.join(directory, "pars_embedded_26.txt")
parameters = read_pars(parameter_path)
t = numpy.linspace(0, 20000, 100)
a = ModelVisualization(model)
data = a.dynamic_view(tspan=t, param_values=parameters, get_passengers=True)

# %%
from visualization.cytoscapejs import viewer as cyjs
from IPython.display import display
q=cyjs.render(data, layout_algorithm='preset')
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset=utf-8 />
#     <link href="http://cdnjs.cloudflare.com/ajax/libs/qtip2/2.2.0/jquery.qtip.min.css" rel="stylesheet" type="text/css" />
#     <style type="text/css">
#         body {
#             font: 14px helvetica neue, helvetica, arial, sans-serif;
#         }
#
#         #cy0c576f29-32ea-4c74-8374-c7b65f855112 {
#             height: 700px;
#             width: 100%;
#             position: absolute;
#             left: 4px;
#             top: 5px;
#             background: #FFFFFF;
#         }
#         #play80daae9c-0019-46f0-9445-05cf0887824f {
#             width: 5%;
#             height: 4%;
#             font-size:130%;
#             position: absolute;
#             top: 93%;
#             left: 10%;
#         }
#
#         #resetbd607a56-2d75-4a23-89b2-1930195d2e62 {
#             width: 5%;
#             height: 4%;
#             font-size:130%;
#             position: absolute;
#             top: 93%;
# ...

# %%
data2 = a.static_view(get_passengers=True)
cyjs.render(data2, layout_algorithm='preset')
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset=utf-8 />
#     <link href="http://cdnjs.cloudflare.com/ajax/libs/qtip2/2.2.0/jquery.qtip.min.css" rel="stylesheet" type="text/css" />
#     <style type="text/css">
#         body {
#             font: 14px helvetica neue, helvetica, arial, sans-serif;
#         }
#
#         #cy4f005001-1c4c-4881-89ce-6586a2f409cb {
#             height: 700px;
#             width: 100%;
#             position: absolute;
#             left: 4px;
#             top: 5px;
#             background: #FFFFFF;
#         }
#         #play5e85cea1-ec8c-4899-aa8e-e922202ec25d {
#             width: 5%;
#             height: 4%;
#             font-size:130%;
#             position: absolute;
#             top: 93%;
#             left: 10%;
#         }
#
#         #reset2bce9821-009c-43ae-ab1a-fdd6b51416c3 {
#             width: 5%;
#             height: 4%;
#             font-size:130%;
#             position: absolute;
#             top: 93%;
# ...
