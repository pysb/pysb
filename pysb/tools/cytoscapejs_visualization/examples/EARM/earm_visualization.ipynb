# %%
from pysb.examples.earm_1_0 import model
import numpy
from pysb.tools.cytoscapejs_visualization.model_visualization_reactions import ModelVisualization
from pysb.tools.cytoscapejs_visualization.util_networkx import from_networkx

t = numpy.linspace(0, 500, 100)
a = ModelVisualization(model)
data = a.dynamic_view(tspan=t, get_passengers=True)

# %%
from pysb.tools.cytoscapejs_visualization.cytoscapejs import viewer as cyjs
from IPython.display import display
q=cyjs.render(data, layout_algorithm='preset')
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset=utf-8 />
#     <link href="http://cdnjs.cloudflare.com/ajax/libs/qtip2/2.2.0/jquery.qtip.min.css" rel="stylesheet" type="text/css" />
#     <style type="text/css">
#         body {
#             font: 14px helvetica neue, helvetica, arial, sans-serif;
#         }
#
#         #cy3b89cf83-a997-47c1-9f03-1db2e0e0f416 {
#             height: 700px;
#             width: 100%;
#             position: absolute;
#             left: 4px;
#             top: 5px;
#             background: #FFFFFF;
#         }
#         #playb0e4dcd7-f435-4ed4-b194-18650f3ceb97 {
#             width: 5%;
#             height: 4%;
#             font-size:130%;
#             position: absolute;
#             top: 93%;
#             left: 10%;
#         }
#
#         #resetd548f49e-83fb-4378-ab13-0fa4c2299bb6 {
#             width: 5%;
#             height: 4%;
#             font-size:130%;
#             position: absolute;
#             top: 93%;
#             left: 16%;
#         }
#
#         #range6ecd64fb-4686-4a43-b089-85e2100f869b {
#             width:80%;
#             height:25px;
#             top:89%;
#             left:10%;
#             border:1px solid black;
#             position:absolute;
#         }
#
#         #text907f3f0f-6112-4465-a96a-f13b83536726 {
#             width:10%;
#             height:5%;
#             top:92.5%;
#             left:24%;
#             font-size:120%;
#             border:0px solid black;
#             position:absolute;
#         }
#         #fitcd88b804-4454-4a71-92d4-317b163d31bc {
#             width: 3em;
#             margin: 0.5em;
#             position: absolute;
#             z-index: 999;
#             top: 0;
#             right: 0;
#         }
#
#         #fitcd88b804-4454-4a71-92d4-317b163d31bc i {
#             transform: rotate(45deg);
#         }
#
#     </style>
#
#     <script>
#         (function() {
#             var all_data ={"elements": {"nodes": [{"position": {"y": 452.0, "x": 27.0}, "data": {"rel_value": [100.0, 99.95982766424434, 99.92011506263039, 99.88085673476246, 99.84204728931955, 99.80368140307927, 99.76575381996633, 99.72825935011632, 99.69119286895426, 99.65454931628858, 99.61832369541862, 99.5825110722571, 99.54710657446604, 99.51210539060573, 99.47750276929884, 99.44329401840625, 99.40947450421704, 99.37603965064912, 99.34298493846224, 99.31030590448525, 99.27799814085652, 99.2460572942738, 99.21447906525484, 99.18325920741032, 99.15239352672843, 99.12187788087058, 99.09170817848137, 99.06188037849623, 99.03239048948193, 99.00323456894591, 98.97440872270967, 98.94590910426841, 98.91773191412874, 98.88987339922355, 98.86232985227782, 98.83509761119042, 98.80817305846344, 98.78155262059664, 98.75523276750833, 98.72921001198335, 98.70348090910986, 98.6780420557052, 98.65289008975367, 98.62802168998994, 98.60343357506486, 98.57912250352835, 98.55508527272634, 98.53131871873106, 98.5078197157516, 98.48458517543838, 98.46161204674938, 98.4388973150871, 98.41643800215363, 98.3942311652657, 98.37227389697615, 98.35056332469438, 98.32909661004365, 98.30787094887819, 98.28688357014089, 98.2661317357766, 98.24561274066534, 98.2253239121014, 98.20526260834409, 98.1854262191093, 98.16581216651397, 98.14641790183639, 98.12724090665229, 98.10827869267081, 98.08952880195451, 98.07098880428296, 98.05265629852607, 98.03452891252117, 98.01660430183433, 97.99888014935016, 97.98135416541311, 97.96402408799305, 97.94688768085754, 97.92994273425937, 97.91318706505776, 97.89661851589389, 97.88023495364499, 97.86403427043383, 97.8480143828499, 97.83217323167716, 97.81650878733899, 97.80101903629784, 97.78570199101974, 97.77055568688169, 97.75557818182031, 97.74076756017766, 97.72612192854866, 97.71163941016432, 97.69731815250148, 97.68315632432693, 97.66915211550045, 97.65530374494632, 97.64160944135753, 97.62806745784358, 97.61467606765294, 97.60143356388964], "name": "s0", "label": "L", "abs_value": [3000.0, 2998.7948299273303, 2997.6034518789115, 2996.4257020428736, 2995.2614186795863, 2994.110442092378, 2992.9726145989903, 2991.8477805034895, 2990.735786068628, 2989.6364794886576, 2988.5497108625586, 2987.475332167713, 2986.4131972339815, 2985.363161718172, 2984.325083078965, 2983.2988205521874, 2982.2842351265112, 2981.2811895194736, 2980.289548153867, 2979.3091771345576, 2978.339944225696, 2977.3817188282137, 2976.434371957645, 2975.4977762223093, 2974.571805801853, 2973.6563364261174, 2972.751245354441, 2971.856411354887, 2970.9717146844578, 2970.097037068377, 2969.2322616812903, 2968.3772731280524, 2967.531957423862, 2966.6962019767066, 2965.8698955683344, 2965.0529283357123, 2964.2451917539033, 2963.4465786178994, 2962.6569830252497, 2961.8763003595004, 2961.1044272732956, 2960.341261671156, 2959.5867026926103, 2958.840650699698, 2958.1030072519457, 2957.3736751058505, 2956.65255818179, 2955.9395615619314, 2955.234591472548, 2954.5375552631517, 2953.8483614024813, 2953.166919452613, 2952.4931400646087, 2951.826934957971, 2951.1682169092846, 2950.5168997408314, 2949.8728983013093, 2949.2361284663457, 2948.6065071042267, 2947.983952073298, 2947.36838221996, 2946.759717363042, 2946.1578782503225, 2945.562786573279, 2944.974364995419, 2944.392537055092, 2943.8172271995686, 2943.248360780124, 2942.6858640586356, 2942.129664128489, 2941.5796889557823, 2941.035867375635, 2940.49812905503, 2939.9664044805045, 2939.440624962393, 2938.9207226397916, 2938.4066304257262, 2937.898282027781, 2937.395611951733, 2936.898555476817, 2936.4070486093497, 2935.921028113015, 2935.440431485497, 2934.9651969503147, 2934.4952636201697, 2934.030571088935, 2933.571059730592, 2933.116670606451, 2932.6673454546094, 2932.2230268053295, 2931.7836578564597, 2931.34918230493, 2930.9195445750443, 2930.4946897298078, 2930.074563465014, 2929.6591123483895, 2929.248283240726, 2928.8420237353075, 2928.440282029588, 2928.043006916689], "background_color": "#1628 ...

# %%
data
# Out:
# {'data': {'name': 'pysb.examples.tyson_oscillator', 'view': 'static'},
#  'elements': {'edges': [{'data': OrderedDict([('arrowhead', 'normal'),
#                  ('source', 's0'),
#                  ('target', 's3')])},
#    {'data': OrderedDict([('arrowhead', 'normal'),
#                  ('source', 's1'),
#                  ('target', 's3')])},
#    {'data': OrderedDict([('arrowhead', 'normal'),
#                  ('source', 's2'),
#                  ('target', 's1')])},
#    {'data': OrderedDict([('arrowhead', 'normal'),
#                  ('source', 's2'),
#                  ('target', 's2')])},
#    {'data': OrderedDict([('arrowhead', 'normal'),
#                  ('source', 's3'),
#                  ('target', 's5')])},
#    {'data': OrderedDict([('arrowhead', 'normal'),
#                  ('source', 's4'),
#                  ('target', 's0')])},
#    {'data': OrderedDict([('arrowhead', 'normal'),
#                  ('source', 's5'),
#                  ('target', 's5')])},
#    {'data': OrderedDict([('arrowhead', 'normal'),
#                  ('source', 's5'),
#                  ('target', 's4')])}],
#   'nodes': [{'data': {'id': 's0', 'name': 's0'},
#     'position': {'x': 117.0, 'y': 18.0}},
#    {'data': {'id': 's1', 'name': 's1'}, 'position': {'x': 117.0, 'y': 72.0}},
#    {'data': {'id': 's2', 'name': 's2'}, 'position': {'x': 27.0, 'y': 72.0}},
#    {'data': {'id': 's3', 'name': 's3'}, 'position': {'x': 207.0, 'y': 64.0}},
#    {'data': {'id': 's4', 'name': 's4'}, 'position': {'x': 387.0, 'y': 41.0}},
#    {'data': {'id': 's5', 'name': 's5'}, 'position': {'x': 297.0, 'y': 64.0}}]}}
