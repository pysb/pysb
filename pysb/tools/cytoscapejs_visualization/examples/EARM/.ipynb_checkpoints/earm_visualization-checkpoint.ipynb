# %%
from earm.lopez_embedded import model
import numpy
import os
from visualization.model_visualization_reactions import ModelVisualization
from tropical.helper_functions import read_pars
from py2cytoscape.util import from_networkx
directory = '/Users/dionisio/PycharmProjects/tropical/examples/EARM/parameters_5000'
parameter_path = os.path.join(directory, "pars_embedded_26.txt")
parameters = read_pars(parameter_path)
t = numpy.linspace(0, 20000, 100)
a = ModelVisualization(model)
data = a.dynamic_view(tspan=t, param_values=parameters, get_passengers=True)

# %%
from visualization.cytoscapejs import viewer as cyjs
from IPython.display import display
q=cyjs.render(data, layout_algorithm='preset')
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset=utf-8 />
#     <link href="http://cdnjs.cloudflare.com/ajax/libs/qtip2/2.2.0/jquery.qtip.min.css" rel="stylesheet" type="text/css" />
#     <style type="text/css">
#         body {
#             font: 14px helvetica neue, helvetica, arial, sans-serif;
#         }
#
#         #cy07bfed52-167d-4fec-a37b-bb816620debe {
#             height: 700px;
#             width: 100%;
#             position: absolute;
#             left: 4px;
#             top: 5px;
#             background: #FFFFFF;
#         }
#         #play400ea508-76d2-40d5-acb1-a1ac3506b3b0 {
#             width: 5%;
#             height: 4%;
#             font-size:130%;
#             position: absolute;
#             top: 93%;
#             left: 10%;
#         }
#
#         #reset015d44e5-a651-4859-a1c3-aa6cd10c2694 {
#             width: 5%;
#             height: 4%;
#             font-size:130%;
#             position: absolute;
#             top: 93%;
#             left: 16%;
#         }
#
#         #range5636bba7-660c-43e1-adb4-d2467cdf4d8e {
#             width:80%;
#             height:25px;
#             top:89%;
#             left:10%;
#             border:1px solid black;
#             position:absolute;
#         }
#
#         #text706081a7-7dc7-44cb-a0e7-5e84e8670091 {
#             width:10%;
#             height:5%;
#             top:92.5%;
#             left:24%;
#             font-size:120%;
#             border:0px solid black;
#             position:absolute;
#         }
#         #fitc464d6c3-403d-4168-84be-371f2defa069 {
#             width: 3em;
#             margin: 0.5em;
#             position: absolute;
#             z-index: 999;
#             top: 0;
#             right: 0;
#         }
#
#         #fitc464d6c3-403d-4168-84be-371f2defa069 i {
#             transform: rotate(45deg);
#         }
#
#     </style>
#
#     <script>
#         (function() {
#             var all_data ={"elements": {"nodes": [{"position": {"y": 862.0, "x": 27.0}, "data": {"rel_value": [100.0, 98.59685456654704, 97.60954017885156, 96.9112504291361, 96.41555397209233, 96.0627229211, 95.81107089530899, 95.63129461173064, 95.50268919636017, 95.41057124835301, 95.34449995846853, 95.29703665365923, 95.2628750567476, 95.23822590307124, 95.22038141478671, 95.20740566272318, 95.19791404343074, 95.19091601588137, 95.18570281503442, 95.18176722817473, 95.17874624062864, 95.17638003446933, 95.17448262972074, 95.17292089922509, 95.17159954595968, 95.17045035165978, 95.16942448155561, 95.16848697630658, 95.16761280931246, 95.16678406444132, 95.16598791573122, 95.16521518115371, 95.16445928730704, 95.16371552827054, 95.16298053503627, 95.1622518956846, 95.16152788347335, 95.16080726217953, 95.16008914674468, 95.15937290351135, 95.15865807880256, 95.15794434779143, 95.15723147789721, 95.15651930257913, 95.15580770257624, 95.15509659247601, 95.15438591109906, 95.15367561461507, 95.15296567161475, 95.15225605958095, 95.15154676236315, 95.15083776836877, 95.1501290692685, 95.14942065906942, 95.14871253345112, 95.14800468929096, 95.14729712432356, 95.14658983689748, 95.14588282580071, 95.14517609013615, 95.14446962923179, 95.14376344257698, 95.14305752977675, 95.1423518905187, 95.14164652454966, 95.14094143165896, 95.14023661166631, 95.1395320644131, 95.13882778975636, 95.13812378756434, 95.13742005771326, 95.13671660008507, 95.13601341456588, 95.13531050104473, 95.13460785941284, 95.13390548956292, 

#             width: 5%;
#             height: 4%;
#             font-size:130%;
#             position: absolute;
#             top: 93%;
#             left: 10%;
#         }
#
#         #reset33960283-1727-4f13-bbd3-72e374dbee3c {
#             width: 5%;
#             height: 4%;
#             font-size:130%;
#             position: absolute;
#             top: 93%;
#             left: 16%;
#         }
#
#         #range4115a97b-f749-4455-8835-8ef454b5ff53 {
#             width:80%;
#             height:25px;
#             top:89%;
#             left:10%;
#             border:1px solid black;
#             position:absolute;
#         }
#
#         #textec22057c-2c78-4d0b-83f5-2c0f66c1c94b {
#             width:10%;
#             height:5%;
#             top:92.5%;
#             left:24%;
#             font-size:120%;
#             border:0px solid black;
#             position:absolute;
#         }
#         #fitc5c29c4d-1172-4504-86b8-538c3263439f {
#             width: 3em;
#             margin: 0.5em;
#             position: absolute;
#             z-index: 999;
#             top: 0;
#             right: 0;
#         }
#
#         #fitc5c29c4d-1172-4504-86b8-538c3263439f i {
#             transform: rotate(45deg);
#         }
#
#     </style>
#
#     <script>
#         (function() {
#             var all_data ={"elements": {"nodes": [{"position": {"y": 862.0, "x": 27.0}, "data": {"font_size": 18, "name": "s0", "label": "L", "shape_cy": "roundrectangle", "background_color": "#162899", "id": "s0"}}, {"position": {"y": 808.0, "x": 27.0}, "data": {"font_size": 18, "name": "s1", "label": "R", "shape_cy": "roundrectangle", "background_color": "#162899", "id": "s1"}}, {"position": {"y": 781.0, "x": 212.22}, "data": {"font_size": 18, "name": "s2", "label": "flip", "shape_cy": "roundrectangle", "background_color": "#162899", "id": "s2"}}, {"position": {"y": 906.0, "x": 212.22}, "data": {"font_size": 18, "name": "s3", "label": "C8pro", "shape_cy": "roundrectangle", "background_color": "#2b913a", "id": "s3"}}, {"position": {"y": 710.0, "x": 462.22}, "data": {"font_size": 18, "name": "s4", "label": "BAR", "shape_cy": "roundrectangle", "background_color": "#162899", "id": "s4"}}, {"position": {"y": 742.0, "x": 2161.4}, "data": {"font_size": 18, "name": "s5", "label": "ApafI", "shape_cy": "roundrectangle", "background_color": "#162899", "id": "s5"}}, {"position": {"y": 883.0, "x": 462.22}, "data": {"font_size": 18, "name": "s6", "label": "C3pro", "shape_cy": "roundrectangle", "background_color": "#2b913a", "id": "s6"}}, {"position": {"y": 802.0, "x": 2788.5}, "data": {"font_size": 18, "name": "s7", "label": "C6pro", "shape_cy": "roundrectangle", "background_color": "#162899", "id": "s7"}}, {"position": {"y": 745.0, "x": 2436.4}, "data": {"font_size": 18, "name": "s8", "label": "C9", "shape_cy": "roundrectangle", "background_color": "#162899", "id": "s8"}}, {"position": {"y": 694.0, "x": 2788.5}, "data": {"font_size": 18, "name": "s9", "label": "PARPU", "shape_cy": "roundrectangle", "background_color": "#162899", "id": "s9"}}, {"position": {"y": 748.0, "x": 3053.5}, "data": {"font_size": 18, "name": "s10", "label": "XIAP", "shape_cy": "roundrectangle", "background_color": "#2b913a", "id": "s10"}}, {"position": {"y": 764.0, "x": 462.22}, "data": {"font_size": 18, "name": "s11", "label": "BidU", "shape_cy": "roundrectangle", "background_color": "#162899", "id": "s11"}}, {"position": {"y": 170.0, "x": 802.82}, "data": {"font_size": 18, "name": "s12", "label": "BaxC", "shape_cy": "roundrectangle", "background_color": "#162899", "id": "s12"}}, {"position": {"y": 730.0, "x": 802.82}, "data": {"font_size": 18, "name": "s13", "label": "BakM", "shape_cy": "roundrectangle", "background_color": "#2b913a", "id": "s13"}}, {"position": {"y": 426.0, "x": 1088.2}, "data": {"font_size": 18, "name": "s14", "label": "Bcl2M", "shape_cy": "roundrectangle", "background_color": "#2b913a", "id": "s14"}}, {"position": {"y": 318.0, "x": 1088.2}, "data": {"font_size": 18, "name": "s15", "label": "BclxLM", "shape_cy": "roundrectangle", "background_color": "#2b913a", "id": "s15"}}, {"position": {"y": 72.0, "x": 802.82}, "data": {"font_size": 18, "name": "s16", "label": "Mcl1M", "shape_cy": "roundrectangle", "background_color": "#2b913a", "id": "s16"}}, {"position": {"y": 372.0, "x": 1088.2}, "data": {"font_size": 18, "name": "s17", "label": "BadM", "shape_cy": "roundrectangle", "background_color": "#2b913a", "id": "s17"}}, {"position": {"y": 18.0, "x": 802.82}, "data": {"font_size": 18, "name": "s18", "label": "NoxaM", "shape_cy": "roundrectangle", "background_color": "#162899", "id": "s18"}}, {"position": {"y": 684.0, "x": 1753.4}, "data": {"font_size": 18, "name": "s19", "label": "CytoCM", "shape_cy": "roundrectangle", "background_color": "#2b913a", "id": "s19"}}, {"position": {"y": 518.0, "x": 1753.4}, "data": {"font_size": 18, "name": "s20", "label": "SmacM", "shape_cy": "roundrectangle", "background_color": "#2b913a", "id": "s20"}}, {"position": {"y": 835.0, "x": 117.0}, "data": {"font_size": 18, "name": "s21", "label": "L_R", "shape_cy": "roundrectangle", "background_color": "#162899", "id": "s21"}}, {"position": {"y": 380.0, "x": 1230.9}, "data": {"font_size": 18, "name": "s22", "label": "BadM_Bcl2M", "shape_cy": "roundrectangle", "background_ ...
